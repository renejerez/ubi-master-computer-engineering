# %% [markdown]
# <div style="Tamplaged                                                                              ">
# <b><center><font size="4">Mestrado em Engenharia Informática</font></center></b>
# <b><center><font size="3">Ciência de Dados</font></center></b>
# <b><center><font size="2">Exame</font></center></b>
#
#
# </div>

# %% [markdown]
# **Notebook Developed by**: [Rene Jerez](https://github.com/renejerez)<br>
# **email:**  rene.jerez@ubi.pt<br>

# %% [markdown]
# <h1>Exame Ciência de Dados<span class="tocSkip"></span></h1>
# <div class="toc">
#   <ul class="toc-item">
#     <li><span><a href="#Setup-and-Load-Data" data-toc-modified-id="Setup-and-Load-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup and Load Data</a></span>
#       <div class="toc">
#         <ul class="toc-item">
#           <li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import libraries</a></span></li>
#           <li><span><a href="#Load-bodyshops-from-CSV-file" data-toc-modified-id="Load-bodyshops-from-CSV-file-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Load bodyshops from CSV file</a></span></li>
#           <li><span><a href="#Find-URLs-for-each-bodyshop" data-toc-modified-id="Find-URLs-for-each-bodyshop-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Find URLs for each bodyshop</a></span></li>
#         </ul>
#       </div>
#     </li>
#     <li><span><a href="#WebDriver-Configuration" data-toc-modified-id="WebDriver-Configuration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>WebDriver Configuration</a></span>
#       <div class="toc">
#         <ul class="toc-item">
#           <li><span><a href="#Configure-and-initialize-Chrome-WebDriver" data-toc-modified-id="Configure-and-initialize-Chrome-WebDriver-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Configure and initialize Chrome WebDriver</a></span></li>
#         </ul>
#       </div>
#     </li>
#     <li><span><a href="#Web-Scraping-and-Data-Extraction" data-toc-modified-id="Web-Scraping-and-Data-Extraction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Web Scraping and Data Extraction</a></span>
#       <div class="toc">
#         <ul class="toc-item">
#           <li><span><a href="#Open-URLs,-handle-pop-ups" data-toc-modified-id="Open-URLs,-handle-pop-ups-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Open URLs, handle pop-ups</a></span></li>
#           <li><span><a href="#Extract-page-content,-scores,-and-'stars'-elements" data-toc-modified-id="Extract-page-content,-scores,-and-'stars'-elements-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Extract page content, scores, and 'stars' elements</a></span></li>
#         </ul>
#       </div>
#     </li>
#     <li><span><a href="#Data-Processing-and-Storage" data-toc-modified-id="Data-Processing-and-Storage-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Processing and Storage</a></span>
#       <div class="toc">
#         <ul class="toc-item">
#           <li><span><a href="#Parse-and-count-star-ratings" data-toc-modified-id="Parse-and-count-star-ratings-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Parse and count star ratings</a></span></li>
#           <li><span><a href="#Store-results-in-DataFrame" data-toc-modified-id="Store-results-in-DataFrame-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Store results in DataFrame</a></span></li>
#         </ul>
#       </div>
#     </li>
#     <li><span><a href="#Final-Data-Integration" data-toc-modified-id="Final-Data-Integration-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Final Data Integration</a></span>
#       <div class="toc">
#         <ul class="toc-item">
#           <li><span><a href="#Merge-extracted-scores-and-reviews-back-into-the-original-DataFrame" data-toc-modified-id="Merge-extracted-scores-and-reviews-back-into-the-original-DataFrame-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Merge extracted scores and reviews back into the original DataFrame</a></span></li>
#         </ul>
#       </div>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <hr>

# %% [markdown]
# # Grupo 1

# %% [markdown]
# ## 1. Descrever duas opções do ciclo de Ciência de Dados

# %% [markdown]
# Data Mining é a etapa no qual seleccionamos os dados. Nesta etapa fazemos a extração de dados de diversas fontes, sejam elas internas ou externas. Também podem ser de fontes privadas ou de fontes públicas. Por exemplo no caso de uma seguradora o data mining ocorre na recolha dos dados internos, veiculos, empresas, morada, como também recolha de dados públicos, como score de reputação da empresa no google review.

# %% [markdown]
# Feature Engineering é a etapa após ter os dados consolidados e preparados para uso, arrancamos a ver quais informações tem maior relevância para o modelo e neste momento começamos a fazer a verificação de cada coluna ou cada informação para saber se aquela informação terá mais valia para os modelos.
# Uma técnica nova utilizada para a feature engineering é utilizar Algoritmos Geneticos para escolha das features e fazer a testagem com o modelo que deve ser utilizado, assim a cada geração do Algoritmo cada grupo de features são testadas e a escolha final será a que terá melhor score/fitness. Este é um exemplo de feature Engineering.

# %% [markdown]
# ## 2. Data lake e Data Warehouse

# %% [markdown]
# Resposta: (2)

# %% [markdown]
# # Grupo 2

# %% [markdown]
# ## 1. Scrapping standvirtual e guardar dataframe

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import numpy as np

import time

# Set up Selenium WebDriver
def setup_driver():
    options = Options()
    options.add_argument('--disable-gpu')  # Disable GPU acceleration
    options.add_argument('--no-sandbox')  # Bypass OS security model
    options.add_argument('--disable-dev-shm-usage')  # Overcome limited resource problems
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    return driver

# Open URL and handle pop-ups
def open_url_and_handle_popups(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

    try:
        accept_cookies_button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Accept all']"))
        )
        accept_cookies_button.click()
        print("Accepted cookies")
    except Exception as e:
        print(f"No cookies button found or another issue: {e}")

    return driver

# Extract product information
def extract_product_info(driver):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    products = []

    for article in soup.find_all('article', class_='item'):
        products.append({'item': str(article)})

    return products

# %%
# Extract product information
def extract_product_info(driver):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    ListOfTagContents = soup.find_all(class_="ooa-de3yyy")
    print(ListOfTagContents)
    [content.get_text() for content in ListOfTagContents]
    return ListOfTagContents

# %%
# Main execution
if __name__ == "__main__":
    driver = setup_driver()
    driver = open_url_and_handle_popups(driver, "https://www.standvirtual.com/destaques")

    all_products = []
    
    while True:
        products = extract_product_info(driver)
        all_products.extend(products)
          
    driver.quit()

    df = pd.DataFrame(all_products)
# Out:
# No cookies button found or another issue: Message:
# Stacktrace:
# 	GetHandleVerifier [0x007C0E73+27667]
# 	(No symbol) [0x00756B74]
# 	(No symbol) [0x00651AFF]
# 	(No symbol) [0x00692BFE]
# 	(No symbol) [0x00692CDB]
# 	(No symbol) [0x006CEC22]
# 	(No symbol) [0x006B3974]
# 	(No symbol) [0x006CCAC7]
# 	(No symbol) [0x006B36C6]
# 	(No symbol) [0x006874D1]
# 	(No symbol) [0x0068804D]
# 	GetHandleVerifier [0x00A73D03+2857635]
# 	GetHandleVerifier [0x00AC7E6D+3202061]
# 	GetHandleVerifier [0x00844674+566292]
# 	GetHandleVerifier [0x0084B86C+595468]
# 	(No symbol) [0x0075F964]
# 	(No symbol) [0x0075C678]
# 	(No symbol) [0x0075C817]
# 	(No symbol) [0x0074E70E]
# 	BaseThreadInitThunk [0x7714FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x772C80CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x772C809E+238]
#
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# [<a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/comerciais/anuncio/opel-combo-longa-l2-c-iva-s-53mil-kms-ID8PGKu3.html">Opel Combo Longa (L2) - C/IVA (Só 53mil kms)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-glb-180-ver-d-amg-line-ID8PGkeW.html">Mercedes-Benz GLB 180 d AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-id-4-ver-pro-performance-1st-ID8PDBRj.html">VW ID.4 Pro Performance 1st</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-94-ah-range-extender-ID8PEO19.html">BMW i3 i3s (94 Ah) Range Extender</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/mercedes-benz-c-400-ver-e-4matic-amg-line-ID8PGMxe.html">Mercedes-Benz C 400 e 4Matic AMG Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/chausson-titanium-ultimate-automtica-nova-ID8PFY1z.html">Chausson Titanium ULTIMATE automática (NOVA)</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/renault-megane-sport-tourer-ver-1-5-blue-dci-r-s-line-ID8PEadg.html">Renault Mégane Sport Tourer 1.5 Blue dCi R.S. Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-bj-40-ID8PySf2.html">Toyota BJ 40</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/ford-s-max-ver-1-8-tdci-titanium-7l-ID8PG7Tf.html">Ford S-Max 1.8 TDCi Titanium 7L</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/citroen-c4-cactus-ver-1-2-puretech-feel-ID8PGPKz.html">Citroën C4 Cactus 1.2 PureTech Feel</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/pesados/anuncio/volvo-fl-4x2r-ID8PClPk.html">Volvo FL-4X2R</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/autostar-passion-i-693-lc-c-central-automtica-ID8PCCby.html">Autostar Passion I 693 LC c.central automática</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-5008-ver-1-5-bluehdi-gt-line-ID8PEvch.html">Peugeot 5008 1.5 BlueHDi GT Line</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/lexus-gs-450h-ver-h8-highpluspele-ID8PFBRQ.html">Lexus GS 450h H8 High+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/hyundai-ioniq-5-ver-5-73kwh-vanguard-ID8PDRC1.html">Hyundai Ioniq 5 73kWh Vanguard</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/peugeot-208-ver-1-2-puretech-like-ID8PGVbs.html">Peugeot 208 1.2 PureTech Like</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/vw-buggy-ID8PGOUh.html">VW Buggy</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/motos/anuncio/husaberg-fe-fe-450-ID8PGPfa.html">Husaberg FE  FE 450</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/nissan-micra-ID8PGPga.html">Nissan Micra</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/autocaravanas/anuncio/mclouis-mc2-ID8PvDCl.html">McLouis MC2</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/toyota-prius-ver-1-8-plug-in-luxurypluspele-ID8PifXs.html">Toyota Prius 1.8 Plug-In Luxury+Pele</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/land-rover-evoque-ver-2-0-ed4-pure-ID8PGIXW.html">Land Rover Range Rover Evoque 2.0 eD4 Pure</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros/anuncio/bmw-i3-ver-i3s-120ah-ID8PGIY2.html">BMW i3 s 120Ah</a>, <a class="ooa-de3yyy" color="#4a4b50" href="https://www.standvirtual.com/carros ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 9
#       6 all_products = []
#       8 while True:
# ----> 9     products = extract_product_info(driver)
#      10     all_products.extend(products)
#      12 driver.quit()
#
# Cell In[13], line 3, in extract_product_info(driver)
#       2 def extract_product_info(driver):
# ----> 3     soup = BeautifulSoup(driver.page_source, 'html.parser')
#       4     ListOfTagContents = soup.find_all(class_="ooa-de3yyy")
#       5     print(ListOfTagContents)
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File c:\Users\rene_\anaconda3\envs\scraper\lib\html\parser.py:311, in HTMLParser.parse_starttag(self, i)
#     309 attrs = []
#     310 match = tagfind_tolerant.match(rawdata, i+1)
# --> 311 assert match, 'unexpected call to parse_starttag()'
#     312 k = match.end()
#     313 self.lasttag = tag = match.group(1).lower()
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import re

# %% [markdown]
# ### Load bodyshops from CSV file

# %%
# Load the CSV file
df = pd.read_csv('bodyshops_to_check.csv')

# %% [markdown]
# ### Find URLs for each bodyshop

# %%
# Step 1: Set up Selenium WebDriver
def setup_driver():
    options = Options()
    options.add_argument('--disable-gpu')  # Disable GPU acceleration
    options.add_argument('--no-sandbox')  # Bypass OS security model
    options.add_argument('--disable-dev-shm-usage')  # Overcome limited resource problems
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    return driver

# Step 2: Open URL and handle pop-ups
def open_url_and_handle_popups(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

    try:
        # Accept cookies pop-up
        accept_cookies_button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Accept all']"))
        )
        accept_cookies_button.click()
        print("Accepted cookies")
    except Exception as e:
        print(f"No cookies button found: {e}")

    return driver

# Step 3: Perform search and get URL
def search_and_get_url(driver, address, name):
    search_box = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, "searchboxinput"))
    )
    search_box.clear()
    search_box.send_keys(address)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)  # Wait for search results to load

    search_box.clear()
    search_box.send_keys(name)
    search_box.send_keys(Keys.ENTER)
    time.sleep(5)  # Wait for search results to load

    current_url = driver.current_url
    return current_url

# Initialize the WebDriver
driver = setup_driver()
driver = open_url_and_handle_popups(driver, "https://www.google.com/maps")

# Iterate through the CSV and perform searches
urls = []
for index, row in df.iterrows():
    address = row['bodyshop_address']
    name = row['nome_prestador_oficina']
    url = search_and_get_url(driver, address, name)
    urls.append(url)

# Add the URLs to the DataFrame
df['url'] = urls

# Save the updated DataFrame back to the same CSV file
df.to_csv(csv_file_path, index=False)

# Close the WebDriver
driver.quit()

# %% [markdown]
# ## 2. criar um dataset de imagens

# %% [markdown]
# # Grupo 3 - Manipulação Numpy

# %% [markdown]
# ## 1. Criar função multiply_arrays

# %%
def multiply_list (li_a, li_b):
    li_c = []
    for i in range (len(li_a)):
        li_c.append(li_a[i]* li_b[i])
        
    return li_c
    # %timeit

# %%
def multiply_arrays (array_a, array_b):
    final_array = array_a * array_b
    return final_array

# %%
li_a = np.arange(0, 20000000).reshape(2, 10000000)
li_b = np.ones((2, 10000000))

# %%
array_a = np.arange(0, 20000000).reshape(2, 10000000)
array_b = np.ones((2, 10000000))

# %%
teste_list = multiply_list(li_a, li_b)
# %timeit

# %%
teste_array = multiply_arrays(array_a, array_b)
# %timeit

# %% [markdown]
# Resposta: A função array parece correr mais rápida vendo que processou o calculo em 0.1s enquanto que a função list foi feita em 0.2s

# %% [markdown]
# # Grupo 4 - Analise de Dados Pandas

# %% [markdown]
# ## 1. Importe o ficheiro housing.csv

# %% [markdown]
# ## 2. Mapear 40 blocos pacote geolocalizaçao

# %% [markdown]
# ## 3. Percentagem de registros nulos total_bedrooms

# %% [markdown]
# ## 4. Valores descritivos da population. Qual é o valor médio da população ?

# %% [markdown]
# ## 5. total de nulos total_bedrooms ocean_proximity é Near By

# %% [markdown]
# ## 6. Substituir nulos pela mediana

# %% [markdown]
# ## 7. criar 3 novos atributos

# %% [markdown]
# ## 8. Desvio Padrão

# %% [markdown]
# ## 9. Mediana population

# %% [markdown]
# # Grupo 5 - Visualização

# %% [markdown]
# ## 1. Heatmap

# %% [markdown]
# # Grupo 6 - LLM NLP

# %% [markdown]
# ## 1. Arquitetura

# %% [markdown]
# Resporta: (b) Redes Neurais Recorrentes (RNNs)

# %% [markdown]
# ## 2. RAG

# %% [markdown]
# Resposta: (b) Um metodo para melhorar a prescição de respostas

# %% [markdown]
# ## 3. Redis

# %% [markdown]
# Resposta: (a) Porque permite a recuperação rápida de embeddings

# %% [markdown]
# # Grupo 7 - Ethics

# %% [markdown]
# ## 1. Data Bias

# %% [markdown]
# Resposta: (b) O modelo aprende e perpetua vieses presentes no dados de treino

# %% [markdown]
# ## 1. COMPAS

# %% [markdown]
# Resposta: (C) Dscriminação Racial

# %% [markdown]
# ## WebDriver Configuration

# %% [markdown]
# ### Configure and initialize Chrome WebDriver

# %%
# Step 1: Set up Selenium WebDriver
def setup_driver():
    options = Options()
    options.add_argument('--disable-gpu')  # Disable GPU acceleration
    options.add_argument('--no-sandbox')  # Bypass OS security model
    options.add_argument('--disable-dev-shm-usage')  # Overcome limited resource problems
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    return driver

# Step 2: Open URL and handle pop-ups
def open_url_and_handle_popups(driver, url):
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

    try:
        # Accept cookies pop-up
        accept_cookies_button = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, "//button[@aria-label='Accept all']"))
        )
        accept_cookies_button.click()
        print("Accepted cookies")
    except Exception as e:
        print(f"No cookies button found: {e}")

    return driver

# Step 3: Extract page content and find the score
def extract_score(driver):
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Locate the score element using aria-label containing "stars"
    score_element = soup.find('span', {'aria-label': lambda x: x and 'stars' in x})
    score = "Score element not found"
    if score_element:
        score = score_element['aria-label']
        print(f"Score (Rating): {score}")
    return score

# Step 4: Extract elements containing 'stars'
def extract_star_elements(driver):
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Locate all elements containing 'stars' in aria-label
    star_elements_info = []
    star_elements = soup.find_all(attrs={'aria-label': lambda x: x and 'stars' in x})
    for element in star_elements:
        star_elements_info.append(f"Element tag: {element.name}, Classes: {element.get('class')}, Aria-label: {element['aria-label']}")
    return star_elements_info

# %% [markdown]
# ## Web Scraping and Data Extraction

# %% [markdown]
# ### Open URLs, handle pop-ups, extract scores and 'stars' elements

# %%
# Main execution
if __name__ == "__main__":
    urls = df['url'].tolist()
    results = []

    driver = setup_driver()
    for url in urls:
        if pd.isna(url) or url.strip() == "":
            results.append("No URL provided")
            continue

        driver = open_url_and_handle_popups(driver, url)
        
        # Extract the score
        score = extract_score(driver)
        
        # Extract star elements information
        star_elements_info = extract_star_elements(driver)
        
        # Combine score and star elements into a single result
        result = f"Score: {score}\n" + "\n".join(star_elements_info)
        
        # Append the data
        results.append(result)
        
        # Keep the browser open for a while to see the result
        time.sleep(10)
    
    # Close the browser
    driver.quit()

    # Add the results to the DataFrame
    df['result'] = results
    
    print("Done")
# Out:
# Accepted cookies
# Score (Rating): 4.1 stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# No cookies button found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0055B8E3+45827]
# 	(No symbol) [0x004EDCC4]
# 	(No symbol) [0x003E150F]
# 	(No symbol) [0x004220BC]
# 	(No symbol) [0x0042216B]
# 	(No symbol) [0x0045E0F2]
# 	(No symbol) [0x00442E44]
# 	(No symbol) [0x0045C034]
# 	(No symbol) [0x00442B96]
# 	(No symbol) [0x00416998]
# 	(No symbol) [0x0041751D]
# 	GetHandleVerifier [0x00814513+2899763]
# 	GetHandleVerifier [0x0086793D+3240797]
# 	GetHandleVerifier [0x005E13B4+593364]
# 	GetHandleVerifier [0x005E82DC+621820]
# 	(No symbol) [0x004F70A4]
# 	(No symbol) [0x004F37A8]
# 	(No symbol) [0x004F3947]
# 	(No symbol) [0x004E59FE]
# 	BaseThreadInitThunk [0x76BFFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7CBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77BC7C8E+238]
#
# Score (Rating):  stars
# Done

# %% [markdown]
# ## Data Processing and Storage

# %% [markdown]
# ### Parse and count star ratings

# %%
# Function to extract star ratings
def extract_star_ratings(result):
    star_counts = {"1 stars": 0, "2 stars": 0, "3 stars": 0, "4 stars": 0, "5 stars": 0}
    matches = re.findall(r'(\d(?:\.\d)?) stars,? (\d+) reviews?', result)
    for match in matches:
        stars = match[0]
        count = int(match[1].replace(',', ''))
        if stars.startswith('1'):
            star_counts["1 stars"] += count
        elif stars.startswith('2'):
            star_counts["2 stars"] += count
        elif stars.startswith('3'):
            star_counts["3 stars"] += count
        elif stars.startswith('4'):
            star_counts["4 stars"] += count
        elif stars.startswith('5'):
            star_counts["5 stars"] += count
    return star_counts

# %% [markdown]
# ### Store results in DataFrame

# %%
# Apply the function to the dataframe
df_star_ratings = df['result'].apply(extract_star_ratings).apply(pd.Series)

# Combine the original dataframe with the new star ratings
df = pd.concat([df, df_star_ratings], axis=1)

# %% [markdown]
# ## Final Data Integration

# %% [markdown]
# ### Merge extracted scores and reviews

# %%
# Function to extract score and review counts
def extract_scores_and_reviews(result):
    matches = re.findall(r'(\d+\.\d) stars (\d+) Reviews?', result)
    return [{"score": float(match[0]), "review": int(match[1].replace(',', ''))} for match in matches]

# Apply the function to extract score and review counts
extracted_data = df['result'].apply(extract_scores_and_reviews)

# Flatten the extracted data and create a new DataFrame
flattened_data = [{"url": row["url"], "score": item["score"], "review": item["review"]} for idx, row in df.iterrows() for item in extracted_data[idx]]
df_scores_reviews = pd.DataFrame(flattened_data)

# Merge the scores and reviews back to the original dataframe on the 'url' column
df = pd.merge(df, df_scores_reviews, on="url", how="left")


# Save the final dataframe to a new CSV file
df.to_csv('bodyshops_to_check_reviews.csv', index=False)

print("Data extraction complete")
# Out:
# Data extraction complete

# %% [markdown]
# New Columns
#
# URL: Path of the Google Maps link for the body shop
#
# Result: Raw HTML information extracted
#
# Stars: Number of stars people rated the body shop
#
# Score: The score people rated the body shop
#
# Review: The number of people who provided a specific score for the body shop
